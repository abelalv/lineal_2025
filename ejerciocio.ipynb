# %% [markdown]
# # primer taller computacional
#
#
# **Objetivo:** El objetivo de la unidad es aplicar operaciones con vectores en R2R2 para analizar el movimiento y trayectoria de objetos, utilizando álgebra lineal y programación en Python para resolver problemas de intersección, optimización de rutas y distancia mínima en un contexto práctico.

# %% [markdown]
# ![Ciclista](ciclista.jpg)

# %% [markdown]
# # Taller: Análisis de Movimiento en una Ciudad
#
# ## Contexto
# En una ciudad con un sistema de coordenadas cartesiano en $\mathbb{R}^2$, se están analizando las rutas de dos mensajeros que se desplazan en bicicleta. Cada uno sigue un trayecto definido por un vector de desplazamiento, y se requiere analizar su relación espacial y eficiencia.
#
#
# Dadas las posiciones iniciales y direcciones de movimiento de los dos ciclistas:
# - Mensajero A parte de **$P_A = (2,3)$** con dirección de movimiento **$v_A = (4,2)$**.
# - Mensajero B parte de **$P_B = (-1,5)$** con dirección **$v_B = (6,3)$**.
#
# ### Se quiere  determinar
#
# 1. Determina la nueva posición de cada ciclista después de **1 unidades de tiempo**, suponiendo que sus desplazamientos siguen sus vectores dirección.
# 2. Si el mensajero A decide moverse al doble de su velocidad, ¿cuál es su nuevo vector de desplazamiento?
# 3. Se quiere determinar si los mensajeros A y B se cruzarán en algún momento. y si se cruzan, ¿en qué punto lo harán y a qué distancia de la posición inicial del mensajero A?
# 4. Suponiendo que los dos mensajeros siguen la misma  trayectoria en la que partieron inicialmente, Existe un paquete que debe ser entregado en la posición **$P = (10,10)$**. ¿Cuál de los dos mensajeros tendría que desviarse menos de la trayectoria para desplazarse  a la posición de entrega?

# %% [markdown]
# ## Preparandose para la solución
#
# Antes de resolver el problema debes escribir que estrategia usarás para resolver cada uno de los puntos anteriores  y su justificación en la celda siguiente.

# %% [markdown]
# ## Calculando la solución
#
# En la siguiente celda escribe el código que te permita resolver el problema planteado. Puedes agregar todas las celdas que consideres necesarias.

# %% [markdown]
# ## Interpretación de la solución
#
# La solución que propongas debes interpretarla si consideras que es correcta o no y por qué. Si no es correcta, debes explicar que es lo que está mal y por qué.

# %% [markdown]
# Recuerda que para resolver el problema usando Python, puedes hacer uso de la librería Numpy para realizar operaciones matriciales y de algebra lineal. Para esta actividad son necesarias las siguientes operaciones:
#
# ```python
# import numpy as np
# u = np.array([3, -6])
# v = np.array([-1, 4])
# print("Vector u:", u)
# print("Vector v:", v)
# print("Suma de vectores u + v:", u + v)
# print("Vector u multiplicado por 2:", 2 * u)
# print("Norma del vector u:", np.linalg.norm(u))
# print("Proyección de u sobre v:", np.dot(u, v) / np.dot(v, v) * v)
# ```
